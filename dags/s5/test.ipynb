# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/renad/venvs/airflow_3.0.6/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/renad/venvs/airflow_3.0.6/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/renad/venvs/airflow_3.0.6/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/renad/venvs/airflow_3.0.6/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 2.3 MB/s  0:00:05 eta 0:00:01
# Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 2.8 MB/s  0:00:06m0:00:0100:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.3.3 pandas-2.3.3

# %%
# never transformation using py ELT
# extract
import requests
import pandas as pd
url = "https://api.escuelajs.co/api/v1/products"
response = requests.get(url)
data = response.json()
# df = pd.DataFrame(products)
# df

# %%
data = pd.json_normalize(data)

# %%
data
# Out:
#       id                              title  \
# 0      1  Majestic Mountain Graphic T-Shirt
# 1      2        Classic Red Pullover Hoodie
# 2      3        Classic Heather Gray Hoodie
# 3      4     Classic Grey Hooded Sweatshirt
# 4      5    Classic Black Hooded Sweatshirt
# ..   ...                                ...
# 109  114                               Grow
# 110  115            Product many laugh film
# 111  116                     Special wonder
# 112  117                     Forward likely
# 113  119                        Draw debate
#
#                                   slug  price  \
# 0    majestic-mountain-graphic-t-shirt     44
# 1          classic-red-pullover-hoodie     10
# 2          classic-heather-gray-hoodie     69
# 3       classic-grey-hooded-sweatshirt     90
# 4      classic-black-hooded-sweatshirt     79
# ..                                 ...    ...
# 109                               grow   1029
# 110            product-many-laugh-film    506
# 111                     special-wonder   4306
# 112                     forward-likely   5064
# 113                        draw-debate   4093
#
#                                            description  \
# 0    Elevate your wardrobe with this stylish black ...
# 1    Elevate your casual wardrobe with our Classic ...
# 2    Stay cozy and stylish with our Classic Heather...
# 3    Elevate your casual wear with our Classic Grey...
# 4    Elevate your casual wardrobe with our Classic ...
# ..                                                 ...
# 109  Very speak forward something ok power real ava...
# 110                         Daughter into speak think.
# 111                             Church education pull.
# 112            Local benefit left worry professor war.
# 113                    Pattern decade film huge dream.
#
#                                                 images  \
# 0    [https://i.imgur.com/QkIa5tT.jpeg, https://i.i...
# 1    [https://i.imgur.com/1twoaDy.jpeg, https://i.i...
# 2    [https://i.imgur.com/cHddUCu.jpeg, https://i.i...
# 3    [https://i.imgur.com/R2PN9Wq.jpeg, https://i.i...
# 4    [https://i.imgur.com/cSytoSD.jpeg, https://i.i...
# ..                                                 ...
# 109  [http://www.griffin.com/categories/searchautho...
# 110  [https://www.davila-smith.com/wp-contenthomepa...
# 111  [http://dunn-hester.net/explore/appterms.htm, ...
# 112  [https://mcbride-carter.com/search/tag/apppost...
# 113  [https://www.nelson.com/blog/postspost.php, ht...
#
#                    creationAt                 updatedAt  category.id  \
# 0    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z            1
# 1    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z            1
# 2    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z            1
# 3    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z            1
# 4    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z            1
# ..                        ...                       ...          ...
# 109  2025-10-04T00:12:57.000Z  2025-10-04T00:12:57.000Z          142
# 110  2025-10-04T00:12:59.000Z  2025-10-04T00:12:59.000Z          143
# 111  2025-10-04T00:12:59.000Z  2025-10-04T00:12:59.000Z          144
# 112  2025-10-04T00:12:59.000Z  2025-10-04T00:12:59.000Z          145
# 113  2025-10-04T00:13:01.000Z  2025-10-04T00:13:01.000Z          147
#
#               category.name           category.slug  \
# 0                   Clothes                 clothes
# 1                   Clothes                 clothes
# 2                   Clothes                 clothes
# 3                   Clothes                 clothes
# 4                   Clothes                 clothes
# ..                      ...                     ...
# 109            Expect think            expect-think
# 110         Drop top ground         drop-top-ground
# 111      Source detail part      source-detail-part
# 112          Skin his bring          skin-his-bring
# 113  Brother keep according  brother-keep-according
#
#                                         category.image  \
# 0                     https://i.imgur.com/QkIa5tT.jpeg
# 1                     https://i.imgur.com/QkIa5tT.jpeg
# 2                     https://i.imgur.com/QkIa5tT.jpeg
# 3                     https://i.imgur.com/QkIa5tT.jpeg
# 4                     https://i.imgur.com/QkIa5tT.jpeg
# ..                                                 ...
# 109         https://mcmahon.com/categories/appfaq.html
# 110  http://www.compton.biz/posts/main/searchhomepa...
# 111  http://www.mitchell-lyons.net/explore/tagabout...
# 112          https://jimenez.com/list/tag/tagmain.html
# 113        http://sawyer.net/explore/searchprivacy.asp
#
#           category.creationAt        category.updatedAt
# 0    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z
# 1    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z
# 2    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z
# 3    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z
# 4    2025-10-03T22:56:52.000Z  2025-10-03T22:56:52.000Z
# ..                        ...                       ...
# 109  2025-10-04T00:12:56.000Z  2025-10-04T00:12:56.000Z
# 110  2025-10-04T00:12:58.000Z  2025-10-04T00:12:58.000Z
# 111  2025-10-04T00:12:58.000Z  2025-10-04T00:12:58.000Z
# 112  2025-10-04T00:12:58.000Z  2025-10-04T00:12:58.000Z
# 113  2025-10-04T00:13:00.000Z  2025-10-04T00:13:00.000Z
#
# [114 rows x 14 columns]

# %%
import duckdb

# %%
conn = duckdb.connect('dev.duckdb')

conn.sql('create table if not exists raw_products as select * from df')

conn.close()
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 conn = duckdb.connect('dev.duckdb')
#       3 conn.sql('create table if not exists raw_products as select * from df')
#       5 conn.close()
#
# IOException: IO Error: Could not set lock on file "/home/renad/airflow/dags/s5/dev.duckdb": Conflicting lock is held in /snap/duckdb/9/duckdb (PID 21167). See also https://duckdb.org/docs/stable/connect/concurrency

# %%
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
