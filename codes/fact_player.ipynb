# %%
import pandas as pd
df =  pd.read_csv(r"C:\Users\HP\Desktop\player_fact_edited1.csv")

# %%
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Columns: 165 entries, Player_id to AvgDist
# dtypes: float64(61), int64(99), object(5)
# memory usage: 683.3+ KB
# None
#    Player_id             Player   Nation    Pos        Squad  \
# 0          1         Max Aarons  eng ENG     DF  Bournemouth
# 1          2  Joshua Acheampong  eng ENG     DF      Chelsea
# 2          3        Tyler Adams   us USA     MF  Bournemouth
# 3          4   Tosin Adarabioyo  eng ENG     DF      Chelsea
# 4          5      Simon Adingra   ci CIV  FW,MF     Brighton
#
#                  Comp   Age    Born  MP  Starts  ...  Att (GK)  Thr  Launch%  \
# 0  eng Premier League  24.0  2000.0   3       1  ...       NaN  NaN      NaN
# 1  eng Premier League  18.0  2006.0   4       2  ...       NaN  NaN      NaN
# 2  eng Premier League  25.0  1999.0  28      21  ...       NaN  NaN      NaN
# 3  eng Premier League  26.0  1997.0  22      15  ...       NaN  NaN      NaN
# ...

# %%
print(df)
# Out:
#      Player_id               Player   Nation    Pos           Squad  \
# 0            1           Max Aarons  eng ENG     DF     Bournemouth
# 1            2    Joshua Acheampong  eng ENG     DF         Chelsea
# 2            3          Tyler Adams   us USA     MF     Bournemouth
# 3            4     Tosin Adarabioyo  eng ENG     DF         Chelsea
# 4            5        Simon Adingra   ci CIV  FW,MF        Brighton
# ..         ...                  ...      ...    ...             ...
# 525        637         Ashley Young  eng ENG     DF         Everton
# 526        538       Illia Zabarnyi   ua UKR     DF     Bournemouth
# 527        539  Oleksandr Zinchenko   ua UKR  DF,MF         Arsenal
# 528        540       Joshua Zirkzee   nl NED  FW,MF  Manchester Utd
# 529        541      Martin Ødegaard   no NOR     MF         Arsenal
#
#                    Comp   Age    Born  MP  Starts  ...  Att (GK)  Thr  \
# 0    eng Premier League  24.0  2000.0   3       1  ...       NaN  NaN
# ...

# %%
df
# Out:
#      Player_id               Player   Nation    Pos           Squad  \
# 0            1           Max Aarons  eng ENG     DF     Bournemouth
# 1            2    Joshua Acheampong  eng ENG     DF         Chelsea
# 2            3          Tyler Adams   us USA     MF     Bournemouth
# 3            4     Tosin Adarabioyo  eng ENG     DF         Chelsea
# 4            5        Simon Adingra   ci CIV  FW,MF        Brighton
# ..         ...                  ...      ...    ...             ...
# 525        637         Ashley Young  eng ENG     DF         Everton
# 526        538       Illia Zabarnyi   ua UKR     DF     Bournemouth
# 527        539  Oleksandr Zinchenko   ua UKR  DF,MF         Arsenal
# 528        540       Joshua Zirkzee   nl NED  FW,MF  Manchester Utd
# 529        541      Martin Ødegaard   no NOR     MF         Arsenal
#
#                    Comp   Age    Born  MP  Starts  ...  Crs_stats_misc  \
# 0    eng Premier League  24.0  2000.0   3       1  ...               2
# ...

# %%
df = df.dropna(axis=1, how="all")

# %%
df = df.fillna(0)

# %%
df
# Out:
#      Player_id               Player   Nation    Pos           Squad  \
# 0            1           Max Aarons  eng ENG     DF     Bournemouth
# 1            2    Joshua Acheampong  eng ENG     DF         Chelsea
# 2            3          Tyler Adams   us USA     MF     Bournemouth
# 3            4     Tosin Adarabioyo  eng ENG     DF         Chelsea
# 4            5        Simon Adingra   ci CIV  FW,MF        Brighton
# ..         ...                  ...      ...    ...             ...
# 525        637         Ashley Young  eng ENG     DF         Everton
# 526        538       Illia Zabarnyi   ua UKR     DF     Bournemouth
# 527        539  Oleksandr Zinchenko   ua UKR  DF,MF         Arsenal
# 528        540       Joshua Zirkzee   nl NED  FW,MF  Manchester Utd
# 529        541      Martin Ødegaard   no NOR     MF         Arsenal
#
#                    Comp   Age    Born  MP  Starts  ...  Crs_stats_misc  \
# 0    eng Premier League  24.0  2000.0   3       1  ...               2
# ...

# %%
df.head()
# Out:
#    Player_id             Player   Nation    Pos        Squad  \
# 0          1         Max Aarons  eng ENG     DF  Bournemouth
# 1          2  Joshua Acheampong  eng ENG     DF      Chelsea
# 2          3        Tyler Adams   us USA     MF  Bournemouth
# 3          4   Tosin Adarabioyo  eng ENG     DF      Chelsea
# 4          5      Simon Adingra   ci CIV  FW,MF     Brighton
#
#                  Comp   Age    Born  MP  Starts  ...  Crs_stats_misc  \
# 0  eng Premier League  24.0  2000.0   3       1  ...               2
# 1  eng Premier League  18.0  2006.0   4       2  ...               0
# 2  eng Premier League  25.0  1999.0  28      21  ...               3
# 3  eng Premier League  26.0  1997.0  22      15  ...               0
# 4  eng Premier League  22.0  2002.0  29      12  ...              41
#
#    Int_stats_misc  TklW_stats_misc  PKwon  PKcon  OG  Recov  Won  \
# 0               1                2      0      0   0      7    0
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Player_id               Player   Nation    Pos           Squad  \
# 0            1           Max Aarons  eng ENG     DF     Bournemouth
# 1            2    Joshua Acheampong  eng ENG     DF         Chelsea
# 2            3          Tyler Adams   us USA     MF     Bournemouth
# 3            4     Tosin Adarabioyo  eng ENG     DF         Chelsea
# 4            5        Simon Adingra   ci CIV  FW,MF        Brighton
# ..         ...                  ...      ...    ...             ...
# 525        637         Ashley Young  eng ENG     DF         Everton
# 526        538       Illia Zabarnyi   ua UKR     DF     Bournemouth
# 527        539  Oleksandr Zinchenko   ua UKR  DF,MF         Arsenal
# 528        540       Joshua Zirkzee   nl NED  FW,MF  Manchester Utd
# 529        541      Martin Ødegaard   no NOR     MF         Arsenal
#
#                    Comp   Age    Born  MP  Starts  ...  Crs_stats_misc  \
# 0    eng Premier League  24.0  2000.0   3       1  ...               2
# ...

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Player_id, Player, Nation, Pos, Squad, Comp, Age, Born, MP, Starts, Min, 90s, Gls, Ast, G+A, G-PK, PK, PKatt, CrdY, CrdR, xG, npxG, xAG, npxG+xAG, G+A-PK, xG+xAG, PrgC, PrgP, PrgR, Sh, SoT, SoT%, Sh/90, SoT/90, G/Sh, G/SoT, Dist, FK, PK_stats_shooting, PKatt_stats_shooting, xG_stats_shooting, npxG_stats_shooting, npxG/Sh, G-xG, np:G-xG, Cmp, Att, Cmp%, TotDist, PrgDist, Ast_stats_passing, xAG_stats_passing, xA, A-xAG, KP, 3-Jan, PPA, CrsPA, PrgP_stats_passing, Live, Dead, FK_stats_passing_types, TB, Sw, Crs, TI, CK, In, Out, Str, Cmp_stats_passing_types, Tkl, TklW, Def 3rd, Mid 3rd, Att 3rd, Att_stats_defense, Tkl%, Lost, Blocks_stats_defense, Sh_stats_defense, Pass, Int, Tkl+Int, Clr, Err, SCA, SCA90, PassLive, PassDead, TO, Sh_stats_gca, Fld, Def, GCA, GCA90, Touches, Def Pen, Def 3rd_stats_possession, Mid 3rd_stats_possession, ...]
# Index: []
#
# [0 rows x 134 columns]

# %%
print(df.columns.tolist())
# Out:
# ['Player_id', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP', 'Starts', 'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'xG', 'npxG', 'xAG', 'npxG+xAG', 'G+A-PK', 'xG+xAG', 'PrgC', 'PrgP', 'PrgR', 'Sh', 'SoT', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'Dist', 'FK', 'PK_stats_shooting', 'PKatt_stats_shooting', 'xG_stats_shooting', 'npxG_stats_shooting', 'npxG/Sh', 'G-xG', 'np:G-xG', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist', 'Ast_stats_passing', 'xAG_stats_passing', 'xA', 'A-xAG', 'KP', '3-Jan', 'PPA', 'CrsPA', 'PrgP_stats_passing', 'Live', 'Dead', 'FK_stats_passing_types', 'TB', 'Sw', 'Crs', 'TI', 'CK', 'In', 'Out', 'Str', 'Cmp_stats_passing_types', 'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Att_stats_defense', 'Tkl%', 'Lost', 'Blocks_stats_defense', 'Sh_stats_defense', 'Pass', 'Int', 'Tkl+Int', 'Clr', 'Err', 'SCA', 'SCA90', 'PassLive', 'PassDead', 'TO', 'Sh_stats_gca', 'Fld', 'Def', 'GCA', 'GCA90', 'Touches', 'Def Pen', 'Def 3rd_st
# ...

# %%
rename_dict = {
    # Player info
    'Player_id': 'player_id',
    'Player': 'player_name',
    'Nation': 'nation',
    'Pos': 'position',
    'Squad': 'club',
    'Comp': 'competition',
    'Age': 'age',
    'Born': 'birth_year',
    
    # Playing stats
    'MP': 'matches_played',
    'Starts': 'starts',
    'Min': 'minutes_played',
    '90s': 'minutes_90',
    'Gls': 'goals',
    'Ast': 'assists',
    'G+A': 'goal_plus_assist',
    'G-PK': 'goal_minus_penalty',
    'PK': 'penalties_scored',
    'PKatt': 'penalty_attempts',
    'CrdY': 'yellow_cards',
    'CrdR': 'red_cards',
    
    # Expected stats
    'xG': 'xG',
    'npxG': 'non_penalty_xG',
    'xAG': 'xAG',
    'npxG+xAG': 'non_penalty_xG_plus_xAG',
    'G+A-PK': 'goal_assist_minus_penalty',
    'xG+xAG': 'xG_plus_xAG',
    'G-xG': 'goals_minus_xG',
    'np:G-xG': 'non_penalty_goals_minus_xG',
    
    # Shooting
    'Sh': 'shots',
    'SoT': 'shots_on_target',
    'SoT%': 'shot_accuracy_pct',
    'Sh/90': 'shots_per_90',
    'SoT/90': 'shots_on_target_per_90',
    'G/Sh': 'goals_per_shot',
    'G/SoT': 'goals_per_shot_on_target',
    'Dist': 'average_shot_distance',
    'FK': 'free_kicks',
    
    # Shooting - advanced
    'PK_stats_shooting': 'penalty_goals_shooting',
    'PKatt_stats_shooting': 'penalty_attempts_shooting',
    'xG_stats_shooting': 'xG_shooting',
    'npxG_stats_shooting': 'non_penalty_xG_shooting',
    'npxG/Sh': 'non_penalty_xG_per_shot',
    
    # Passing
    'Cmp': 'passes_completed',
    'Att': 'passes_attempted',
    'Cmp%': 'pass_accuracy_pct',
    'TotDist': 'total_distance_passed',
    'PrgDist': 'progressive_distance_passed',
    'Ast_stats_passing': 'assists_passing',
    'xAG_stats_passing': 'xAG_passing',
    'xA': 'xA',
    'A-xAG': 'assists_minus_xAG',
    'KP': 'key_passes',
    '3-Jan': 'through_balls',
    'PPA': 'passes_into_final_third',
    'CrsPA': 'crosses_into_box',
    'PrgP_stats_passing': 'progressive_passes',
    'Live': 'live_ball_passes',
    'Dead': 'dead_ball_passes',
    'FK_stats_passing_types': 'free_kick_passes',
    'TB': 'throw_ins',
    'Sw': 'switches',
    'Crs': 'crosses',
    'TI': 'throw_ins',  # إذا TI معناها throw-ins
    'CK': 'corners',
    'In': 'dribbles_in',
    'Out': 'dribbles_out',
    'Str': 'successful_dribbles',
    
    # Defense
    'Tkl': 'tackles',
    'TklW': 'tackles_won',
    'Def 3rd': 'def_third',
    'Mid 3rd': 'mid_third',
    'Att 3rd': 'att_third',
    'Att_stats_defense': 'attacking_defense_actions',
    'Tkl%': 'tackle_success_pct',
    'Lost': 'lost_balls',
    'Blocks_stats_defense': 'blocks',
    'Sh_stats_defense': 'shots_blocked',
    'Pass': 'passes_blocked',
    'Int': 'interceptions',
    'Tkl+Int': 'tackles_plus_interceptions',
    'Clr': 'clearances',
    'Err': 'errors',
    
    # Goal creation
    'SCA': 'shot_creating_actions',
    'SCA90': 'sca_per_90',
    'PassLive': 'live_passes_sca',
    'PassDead': 'dead_passes_sca',
    'TO': 'turnovers',
    'Sh_stats_gca': 'shots_goal_creating_actions',
    
    # Possession
    'Def 3rd_stats_possession': 'def_third_possession',
    'Mid 3rd_stats_possession': 'mid_third_possession',
    'Att 3rd_stats_possession': 'att_third_possession',
    '1/3_stats_possession': 'final_third_possession',
    'PrgC_stats_possession': 'progressive_carries_possession',
    'PrgDist_stats_possession': 'progressive_distance_possession',
    'TotDist_stats_possession': 'total_distance_possession',
    'PrgR_stats_possession': 'progressive_runs_possession',
    'Live_stats_possession': 'live_possession',
    'Att_stats_possession': 'attacking_possession',
    'Succ': 'successful_dribbles_possession',
    'Succ%': 'successful_dribbles_pct',
    'Tkld': 'tackled',
    'Tkld%': 'tackled_pct',
    'Carries': 'carries',
    'CPA': 'crosses_into_box_possession',
    'Mis': 'miscontrols',
    'Dis': 'dispossessed',
    'Rec': 'recoveries',
    
    # Miscellaneous
    'CrdY_stats_misc': 'yellow_cards_misc',
    'CrdR_stats_misc': 'red_cards_misc',
    '2CrdY': 'second_yellow',
    'Fls': 'fouls',
    'Fld_stats_misc': 'fouls_field',
    'Off_stats_misc': 'offsides',
    'Crs_stats_misc': 'crosses_misc',
    'Int_stats_misc': 'interceptions_misc',
    'TklW_stats_misc': 'tackles_won_misc',
    'PKwon': 'penalties_won',
    'PKcon': 'penalties_conceded',
    'OG': 'own_goals',
    'Recov': 'recoveries_misc',
    'Won': 'duels_won',
    'Lost_stats_misc': 'lost_misc',
    'Won%': 'win_pct'
}

df.rename(columns=rename_dict, inplace=True)

# %%
df
# Out:
#      player_id          player_name   nation position            club  \
# 0            1           Max Aarons  eng ENG       DF     Bournemouth
# 1            2    Joshua Acheampong  eng ENG       DF         Chelsea
# 2            3          Tyler Adams   us USA       MF     Bournemouth
# 3            4     Tosin Adarabioyo  eng ENG       DF         Chelsea
# 4            5        Simon Adingra   ci CIV    FW,MF        Brighton
# ..         ...                  ...      ...      ...             ...
# 525        637         Ashley Young  eng ENG       DF         Everton
# 526        538       Illia Zabarnyi   ua UKR       DF     Bournemouth
# 527        539  Oleksandr Zinchenko   ua UKR    DF,MF         Arsenal
# 528        540       Joshua Zirkzee   nl NED    FW,MF  Manchester Utd
# 529        541      Martin Ødegaard   no NOR       MF         Arsenal
#
#             competition   age  birth_year  matches_played  starts  ...  \
# ...

# %%
import os
desktop = os.path.join(os.path.expanduser("~"), "Desktop")
df.to_csv(os.path.join(desktop, 'player_fact_clean.csv'), index=False, encoding='utf-8-sig')
print("done")
# Out:
# done
